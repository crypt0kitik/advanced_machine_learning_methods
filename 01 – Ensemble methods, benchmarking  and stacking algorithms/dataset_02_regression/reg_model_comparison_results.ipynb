# %% [markdown]
# # Model comparison results

# %% [markdown]
# # 01 - Logistic Regression (regression)
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 02 - XGBoost
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 03 - CatBoost
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 04 - AdaBoost
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 05 - LightGBM
# ![image.png](attachment:image.png)

# %% [markdown]
# # 06 - Random Forest

# %% [markdown]
# # 07 - KNN (K-Nearest Neighbors)

# %% [markdown]
# # 08 - SVM (Support Vector Machine)

# %% [markdown]
# # 09 - Ridge (Lasso) Regression

# %% [markdown]
# # 10 - Stacking Classifier
