# %% [markdown]
# # Sentence Tokenization

# %%
# I had an issue with NLTK
# that is I opted for spacy
import spacy
import subprocess
import pandas as pd

# %%
# Function to download and load spaCy model
def download_spacy_model():
    try:
        spacy.load("en_core_web_sm")
    except OSError:
        print("Downloading 'en_core_web_sm' model...")
        subprocess.run(["python", "-m", "spacy", "download", "en_core_web_sm"], check=True)
        print("Download complete!")

# Ensure spaCy model is available
download_spacy_model()

# %%
# Load the English NLP model
nlp = spacy.load("en_core_web_sm")

# %%
def sentence_tokenization(text):
    """
    Function to tokenize text into sentences using spaCy.
    :param text: str, input text
    :return: list, tokenized sentences
    """
    doc = nlp(text)  # Process the text using spaCy
    return [sent.text for sent in doc.sents]  # Extract sentence tokens

# %%
# Load dataset
file_path = "all_numeric_survey_labels.csv" 
text_columns = ["tableau_usage_pre", "api_usage_pre", "ml_application_pre",
                    "persona_explanation_pre", "api_usage_pre", "ml_application_pre",
                    "data_collection_explanation_post", "data_analysis_explanation_post", "persona_building_explanation_post",
                    "evaluation_explanation_post", "tools_usage_post", "api_usage_post",
                    "ml_application_post"]

# %%
try:
    df = pd.read_csv(file_path)  # Load CSV file
    print("Dataset loaded successfully!")

    # Apply lemmatization to each text column
    for col in text_columns:
        if col in df.columns:  # Ensure column exists before processing
            df[col] = df[col].astype(str).apply(sentence_tokenization)

    # Save the processed dataset
    output_file = "01.3_df_sentence_token.csv"
    df.to_csv(output_file, index=False)
    print(f"Processed dataset saved as {output_file}")

except Exception as e:
    print(f"Error loading dataset: {e}")
# Out:
# Dataset loaded successfully!
# Processed dataset saved as 01.3_df_sentence_token.csv

# %%
# Display the cleaned dataset
# Ensure all columns are displayed
pd.set_option("display.max_columns", None)
df.head(5)
# Out:
#   start_date_pre  end_date_pre  ip_address_pre  duration_sec_pre  \
# 0   2/13/25 0:10  2/13/25 0:16  193.166.113.18               372
# 1   2/13/25 0:09  2/13/25 0:16  193.166.113.32               409
# 2   2/13/25 0:09  2/13/25 0:17  193.166.113.31               462
# 3   2/13/25 0:11  2/13/25 0:17  193.166.113.21               355
# 4   2/13/25 0:09  2/13/25 0:18   193.166.117.7               551
#
#      response_id_pre  LocationLatitude_pre  LocationLongitude_pre  \
# 0  R_8GBoA0i1k6yogS1               63.1198                21.6798
# 1  R_8QG2UV0Zv0fKVB5               63.1198                21.6798
# 2  R_8tHW5RDZd4yBkcx               63.1198                21.6798
# 3  R_8462bTis2cTNcii               63.1198                21.6798
# 4  R_824J8ZB9ZGfOu8t               63.1198                21.6798
#
#    DistributionChannel_pre  UserLanguage_pre  participant_id  age_pre  \
# 0                        0                 0               1       60
# 1                        0                 0              23       41
# 2                        0                 0              22       45
# 3                        0                 0              19       39
# 4                        0                 0              15       38
#
#    gender_pre  occupation_pre  teaching_marketing_pre teaching_experience_pre  \
# 0           1               1                       1                      20
# 1           1               2                       2                       0
# 2           1               2                       1                       3
# 3           1               2                       1                       1
# 4           2               2                       2                       0
#
#   learning_style_pre learning_format_pre interaction_preference_pre  \
# 0                  3                 3,4                        3,4
# 1              1,3,4                 2,4                        3,4
# 2                1,3                 3,4                        3,4
# 3            1,2,3,4                 3,4                        3,4
# 4              1,2,4                   4                        3,4
#
#   trusted_learning_method_pre  ai_familiarity_pre  ddp_familiarity_pre  \
# 0                       2,3,4                  12                   10
# 1                       2,3,4                  10                    1
# 2                       2,3,4                  11                   10
# 3                       2,3,4                  12                    1
# 4                           2                  12                    1
#
#   data_sources_pre  persona_definition_pre  interactive_persona_pre  \
# 0                4                       1                        2
# 1                4                       1                        2
# 2              1,3                       1                        5
# 3                4                       1                        5
# 4                5                       5                        5
#
#    data_driven_persona_pre  dynamic_persona_pre  \
# 0                        2                    1
# 1                        2                    1
# 2                        2                    5
# 3                        2                    5
# 4                        5                    5
#
#                                   tableau_usage_pre  \
# 0                                   [I do not know]
# 1  [I do not know these tools, so I cannot answer.]
# 2                                   [I don't know.]
# 3                                             [nan]
# 4                                               [-]
#
#                              api_usage_pre     ml_application_pre  \
# 0                      [['I do not know']]    [['I do not know']]
# 1                    [['I have no clue.']]  [['I have no clue.']]
# 2  [["I don't know what API stands for."]]    [["I don't know."]]
# 3                                [['nan']]              [['nan']]
# 4                                  [['-']]                [['-']]
#
#   persona_explanation_pre  confirmation_pre      start_date_post  \
# 0         [I do not know]                 0   2025-02-13 0:56:11
# 1       [I have no clue.]                 0   2025-02-13 0:56:02
# 2         [I don't know.]                 0  2025-02-13 10:06:34
# 3                   [nan]                 0   2025-02-13 0:55:51
# 4                     [-]                 0   2025-02-13 0:55:35
#
#          end_date_post ip_address_post  duration_sec_post   response_id_post  \
# 0   2025-02-13 1:18:59  193.166.113.18               1368  R_8QL21bpDcdbdtJ4
# 1   2025-02-13 1:13:21  193.166.113.32               1039  R_8QrAaCxxXwbpxvL
# 2  2025-02-13 10:19:38  193.166.113.31                784  R_2kRKZFGiWHUQidw
# 3   2025-02-13 1:11:01  193.166.113.21                909  R_2M3diy3SR17ual3
# 4   2025-02-13 1:19:16   193.166.117.7               1421  R_2KPeTVjwHtRdvU7
#
#    LocationLatitude_post  LocationLongitude_post  DistributionChannel_post  \
# 0                63.1198                 21.6798                         0
# 1                63.1198                 21.6798                         0
# 2                63.1198                 21.6798                         0
# 3                63.1198                 21.6798                         0
# 4                63.1198                 21.6798                         0
#
#    UserLanguage_post                   data_collection_explanation_post  \
# 0                  0  [to collect studens' demographic data, data of...
# 1                  0  [User analytics: Google analytics, CRM, APIs e...
# 2                  0  [I need quantitative data, which can be obtain...
# 3                  0  [Data sources: Attendance, group tasks evaluat...
# 4                  0  [-age, jobs, demographic data, how they behave...
#
#                       data_analysis_explanation_post  \
# 0  [First the data must be cleaned., to achieve h...
# 1  [Segmentation can be performed so that each pe...
# 2  [Statistical analyses are required., These inc...
# 3  [Clustering, matrix for patterns, AI or softwa...
# 4  [-clustering students according to their goals...
#
#                    persona_building_explanation_post  Unnamed: 43  \
# 0  [After clustering and combining, the personas ...            1
# 1  [One way to create student personas it is to i...            2
# 2  [In this stage, crafting the persona profiles ...            3
# 3  [use the data and build representative persona...            4
# 4  [-making descriptive profile posters for each ...            5
#
#                          evaluation_explanation_post  ai_familiarity_post  \
# 0  [The evaluation can be done e.g., with traditi...                    4
# 1  [1) I have not been teaching marketing courses...                    2
# 2  [This is a crucial step in the persona buildin...                    3
# 3  [test within the existing network to see if th...                    4
# 4  [-personas should not become static but they m...                    4
#
#    ddp_familiarity_post data_sources_post  persona_definition_post  \
# 0                     4  All of the above                        0
# 1                     2  All of the above                        0
# 2                     4  All of the above                        0
# 3                     5  All of the above                        0
# 4                     2  All of the above                        0
#
#    interactive_persona_post  data_driven_persona_post  dynamic_persona_post  \
# 0                         1                         0                     0
# 1                         1                         0                     0
# 2                         2                         0                     1
# 3                         1                         0                     0
# 4                         1                         0                     0
#
#                                     tools_usage_post  \
# 0  [To communicate the personas to the users., To...
# 1  [To illustrate (and update) static persona pro...
# 2                        [To visualise the persona.]
# 3                                    [data analysis]
# 4  [To make posters of the persona so that everyo...
#
#                                       api_usage_post  \
# 0  [Because relevant data can be obtained from th...
# 1                      [I have no clue what is API.]
# 2                 [I dont know what API stands for.]
# 3                                  [to collect data]
# 4         [For analysis?, I don't know what is API.]
#
#                                  ml_application_post  \
# 0  [They can be used e.g., in clustering and comb...
# 1                      [To create dynamic personas.]
# 2                                    [I don't know.]
# 3  [To a great deal., can help process large amou...
# 4  [To develop personas further when new informat...
#
#    engagement_experience_post  interaction_quality_post  \
# 0                           5                         1
# 1                           4                         2
# 2                           3                         4
# 3                           6                         6
# 4                           4                         2
#
#    communication_clarity_post  trustworthiness_post  emotional_response_post  \
# 0                           7                     2                        2
# 1                           4                     4                        2
# 2                           6                     6                        1
# 3                           6                     4                        2
# 4                           3                     3                        1
#
#    naturalness_post  effectiveness_post  comfort_level_post  \
# 0                 1                   6                   6
# 1                 4                   4                   2
# 2                 4                   5                   3
# 3                 3                   6                   1
# 4                 4                   3                   6
#
#    personalization_post  mental_effort_post persona_definition_pre_grade  \
# 0                     1                   4                      Correct
# 1                     2                   6                      Correct
# 2                     4                   5                      Correct
# 3                     4                   4                      Correct
# 4                     1                   6                  Not Correct
#
#   persona_definition_post_grade persona_definition_grade_comparison  \
# 0                   Not Correct                            DECLINED
# 1                   Not Correct                            DECLINED
# 2                   Not Correct                            DECLINED
# 3                   Not Correct                            DECLINED
# 4                   Not Correct                                SAME
#
#   interactive_persona_pre_grade interactive_persona_post_grade  \
# 0                       Correct                        Correct
# 1                       Correct                        Correct
# 2                   Not Correct                    Not Correct
# 3                   Not Correct                        Correct
# 4                   Not Correct                        Correct
#
#   interactive_persona_grade_comparison data_driven_persona_pre_grade  \
# 0                                 SAME                       Correct
# 1                                 SAME                       Correct
# 2                                 SAME                       Correct
# 3                             IMPROVED                       Correct
# 4                             IMPROVED                   Not Correct
#
#   data_driven_persona_post_grade data_driven_persona_grade_comparison  \
# 0                    Not Correct                             DECLINED
# 1                    Not Correct                             DECLINED
# 2                    Not Correct                             DECLINED
# 3                    Not Correct                             DECLINED
# 4                    Not Correct                                 SAME
#
#   dynamic_persona_pre_grade dynamic_persona_post_grade  \
# 0                   Correct                Not Correct
# 1                   Correct                Not Correct
# 2               Not Correct                    Correct
# 3               Not Correct                Not Correct
# 4               Not Correct                Not Correct
#
#   dynamic_persona_grade_comparison data_collection_explanation_post_grade  \
# 0                         DECLINED                                   HIGH
# 1                         DECLINED                                    LOW
# 2                         IMPROVED                                 MEDIUM
# 3                             SAME                                   HIGH
# 4                             SAME                                 MEDIUM
#
#   data_analysis_explanation_post_grade  \
# 0                                  LOW
# 1                                 HIGH
# 2                                 HIGH
# 3                               MEDIUM
# 4                               MEDIUM
#
#   persona_building_explanation_post_grade evaluation_explanation_post_grade  \
# 0                                    HIGH                            MEDIUM
# 1                                     LOW                              HIGH
# 2                                    HIGH                              HIGH
# 3                                  MEDIUM                            MEDIUM
# 4                                     LOW                            MEDIUM
#
#   group_class
# 0     Chatbot
# 1     Chatbot
# 2    Deepfake
# 3     Chatbot
# 4     Chatbot
