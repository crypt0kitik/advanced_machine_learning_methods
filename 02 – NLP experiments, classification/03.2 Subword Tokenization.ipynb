# %% [markdown]
# # Subword Tokenization

# %%
# import libraries

# pip install tokenizers

import spacy
import subprocess
import pandas as pd
from tokenizers import ByteLevelBPETokenizer

# %%
# Load dataset
file_path = "all_numeric_survey.csv" 
text_columns = ["tableau_usage_pre", "api_usage_pre", "ml_application_pre",
                    "persona_explanation_pre", "api_usage_pre", "ml_application_pre",
                    "data_collection_explanation_post", "data_analysis_explanation_post", "persona_building_explanation_post",
                    "evaluation_explanation_post", "tools_usage_post", "api_usage_post",
                    "ml_application_post"]

# %%
try:
    df = pd.read_csv(file_path)  # Load CSV file
    print("Dataset loaded successfully!")

    # Initialize and train the BPE tokenizer on dataset text
    tokenizer = ByteLevelBPETokenizer()
    
    # Combine all text from the selected columns for training
    all_text = df[text_columns].astype(str).values.flatten()
    tokenizer.train_from_iterator(all_text)

    # Function to apply BPE tokenization
    def tokenize_text(text):
        return " ".join(tokenizer.encode(text).tokens) if pd.notna(text) else ""

    # Apply BPE tokenization to each text column
    for col in text_columns:
        if col in df.columns:
            df[col] = df[col].astype(str).apply(tokenize_text)

    # Save the processed dataset
    output_file = "dataset_subword_token.csv"
    df.to_csv(output_file, index=False)
    print(f"Processed dataset saved as {output_file}")

except Exception as e:
    print(f"Error loading dataset: {e}")
# Out:
# Dataset loaded successfully!
# Processed dataset saved as dataset_subword_token.csv

# %%
# Display the cleaned dataset
# Ensure all columns are displayed
pd.set_option("display.max_columns", None)
df.head(5)
# Out:
#   start_date_pre  end_date_pre  ip_address_pre  duration_sec_pre  \
# 0   2/13/25 0:10  2/13/25 0:16  193.166.113.18               372
# 1   2/13/25 0:09  2/13/25 0:16  193.166.113.32               409
# 2   2/13/25 0:09  2/13/25 0:17  193.166.113.31               462
# 3   2/13/25 0:11  2/13/25 0:17  193.166.113.21               355
# 4   2/13/25 0:09  2/13/25 0:18   193.166.117.7               551
#
#      response_id_pre  LocationLatitude_pre  LocationLongitude_pre  \
# 0  R_8GBoA0i1k6yogS1               63.1198                21.6798
# 1  R_8QG2UV0Zv0fKVB5               63.1198                21.6798
# 2  R_8tHW5RDZd4yBkcx               63.1198                21.6798
# 3  R_8462bTis2cTNcii               63.1198                21.6798
# 4  R_824J8ZB9ZGfOu8t               63.1198                21.6798
#
#    DistributionChannel_pre  UserLanguage_pre  participant_id  age_pre  \
# 0                        0                 0               1       60
# 1                        0                 0              23       41
# 2                        0                 0              22       45
# 3                        0                 0              19       39
# 4                        0                 0              15       38
#
#    gender_pre  occupation_pre  teaching_marketing_pre teaching_experience_pre  \
# 0           1               1                       1                      20
# 1           1               2                       2                       0
# 2           1               2                       1                       3
# 3           1               2                       1                       1
# 4           2               2                       2                       0
#
#   learning_style_pre learning_format_pre interaction_preference_pre  \
# 0                  3                 3,4                        3,4
# 1              1,3,4                 2,4                        3,4
# 2                1,3                 3,4                        3,4
# 3            1,2,3,4                 3,4                        3,4
# 4              1,2,4                   4                        3,4
#
#   trusted_learning_method_pre  ai_familiarity_pre  ddp_familiarity_pre  \
# 0                       2,3,4                  12                   10
# 1                       2,3,4                  10                    1
# 2                       2,3,4                  11                   10
# 3                       2,3,4                  12                    1
# 4                           2                  12                    1
#
#   data_sources_pre  persona_definition_pre  interactive_persona_pre  \
# 0                4                       1                        2
# 1                4                       1                        2
# 2              1,3                       1                        5
# 3                4                       1                        5
# 4                5                       5                        5
#
#    data_driven_persona_pre  dynamic_persona_pre  \
# 0                        2                    1
# 1                        2                    1
# 2                        2                    5
# 3                        2                    5
# 4                        5                    5
#
#                                    tableau_usage_pre  \
# 0                                   I Ġdo Ġnot Ġknow
# 1  I Ġdo Ġnot Ġknow Ġthese Ġtools , Ġso ĠI Ġcanno...
# 2                                  I Ġdon 't Ġknow .
# 3                                                nan
# 4                                                  -
#
#                                        api_usage_pre  \
# 0                  I Ġ Ä ł d o Ġ Ä ł not Ġ Ä ł k now
# 1      I Ġ Ä ł ha ve Ġ Ä ł no Ġ Ä ł c l ue Ġ . Ġ Ä ł
# 2  I Ġ Ä ł don Ġ ' t Ġ Ä ł k now Ġ Ä ł w hat Ġ Ä ...
# 3                                                nan
# 4                                                  -
#
#                         ml_application_pre persona_explanation_pre  \
# 0        I Ġ Ä ł d o Ġ Ä ł not Ġ Ä ł k now        I Ġdo Ġnot Ġknow
# 1  I Ġ Ä ł ha ve Ġ Ä ł no Ġ Ä ł c l ue Ġ .     I Ġhave Ġno Ġclue .
# 2        I Ġ Ä ł don Ġ ' t Ġ Ä ł k now Ġ .       I Ġdon 't Ġknow .
# 3                                      nan                     nan
# 4                                        -                       -
#
#    confirmation_pre      start_date_post        end_date_post ip_address_post  \
# 0                 0   2025-02-13 0:56:11   2025-02-13 1:18:59  193.166.113.18
# 1                 0   2025-02-13 0:56:02   2025-02-13 1:13:21  193.166.113.32
# 2                 0  2025-02-13 10:06:34  2025-02-13 10:19:38  193.166.113.31
# 3                 0   2025-02-13 0:55:51   2025-02-13 1:11:01  193.166.113.21
# 4                 0   2025-02-13 0:55:35   2025-02-13 1:19:16   193.166.117.7
#
#    duration_sec_post   response_id_post  LocationLatitude_post  \
# 0               1368  R_8QL21bpDcdbdtJ4                63.1198
# 1               1039  R_8QrAaCxxXwbpxvL                63.1198
# 2                784  R_2kRKZFGiWHUQidw                63.1198
# 3                909  R_2M3diy3SR17ual3                63.1198
# 4               1421  R_2KPeTVjwHtRdvU7                63.1198
#
#    LocationLongitude_post  DistributionChannel_post  UserLanguage_post  \
# 0                 21.6798                         0                  0
# 1                 21.6798                         0                  0
# 2                 21.6798                         0                  0
# 3                 21.6798                         0                  0
# 4                 21.6798                         0                  0
#
#                     data_collection_explanation_post  \
# 0  to Ġcollect Ġstud en s ' Ġdemographic Ġdata , ...
# 1  User Ġanalytics : ĠGoogle Ġanalytics , ĠCRM , ...
# 2  I Ġneed Ġquantitative Ġdata , Ġwhich Ġcan Ġbe ...
# 3  Data Ġsources : ĠA t t end ance , Ġgroup Ġtask...
# 4  - age , Ġjobs , Ġdemographic Ġdata , Ġhow Ġthe...
#
#                       data_analysis_explanation_post  \
# 0  First Ġthe Ġdata Ġmust Ġbe Ġcle an ed . Ġto Ġa...
# 1  Segment ation Ġcan Ġbe Ġperform ed Ġso Ġthat Ġ...
# 2  S t at istical Ġanalyses Ġare Ġre qu ire d . Ġ...
# 3  C lustering , Ġmat rix Ġfor Ġpatterns , ĠAI Ġo...
# 4  - c lustering Ġstudents Ġaccording Ġto Ġtheir ...
#
#                    persona_building_explanation_post  \
# 0  After Ġclustering Ġand Ġcombining , Ġthe Ġpers...
# 1  One Ġway Ġto Ġcreate Ġstudent Ġpersonas Ġit Ġi...
# 2  In Ġthis Ġstage , Ġcr af ting Ġthe Ġpersona Ġp...
# 3  use Ġthe Ġdata Ġand Ġbuild Ġrepresentative Ġpe...
# 4  - ma king Ġdescriptive Ġprofile Ġposters Ġfor ...
#
#                          evaluation_explanation_post  ai_familiarity_post  \
# 0  The Ġevaluation Ġcan Ġbe Ġdone Ġe . g ., Ġwith...                    4
# 1  1 ) ĠI Ġhave Ġnot Ġbeen Ġteaching Ġmarketing Ġ...                    2
# 2  This Ġis Ġa Ġcr u cial Ġstep Ġin Ġthe Ġpersona...                    3
# 3  test Ġwith in Ġthe Ġexisting Ġn et wor k Ġto Ġ...                    4
# 4  - p ersonas Ġshould Ġnot Ġbecome Ġstatic Ġbut ...                    4
#
#    ddp_familiarity_post data_sources_post  persona_definition_post  \
# 0                     4  All of the above                        0
# 1                     2  All of the above                        0
# 2                     4  All of the above                        0
# 3                     5  All of the above                        0
# 4                     2  All of the above                        0
#
#    interactive_persona_post  data_driven_persona_post  dynamic_persona_post  \
# 0                         1                         0                     0
# 1                         1                         0                     0
# 2                         2                         0                     1
# 3                         1                         0                     0
# 4                         1                         0                     0
#
#                                     tools_usage_post  \
# 0  To Ġcommunicate Ġthe Ġpersonas Ġto Ġthe Ġusers...
# 1  To Ġillustr ate Ġ( and Ġupdate ) Ġstatic Ġpers...
# 2                     To Ġvisual ise Ġthe Ġpersona .
# 3                                   data Ġanalysis Ġ
# 4  To Ġmake Ġposters Ġof Ġthe Ġpersona Ġso Ġthat ...
#
#                                       api_usage_post  \
# 0  B ec ause Ġrelevant Ġdata Ġcan Ġbe Ġobtained Ġ...
# 1                 I Ġhave Ġno Ġclue Ġwhat Ġis ĠAPI .
# 2           I Ġdon t Ġknow Ġwhat ĠAPI Ġstands Ġfor .
# 3                                to Ġcollect Ġdata Ġ
# 4  For Ġanalysis ? ĠI Ġdon 't Ġknow Ġwhat Ġis ĠAPI .
#
#                                  ml_application_post  \
# 0  They Ġcan Ġbe Ġused Ġe . g ., Ġin Ġclustering ...
# 1                  To Ġcreate Ġdynamic Ġpersonas . Ġ
# 2                                  I Ġdon 't Ġknow .
# 3  To Ġa Ġgre at Ġde al . Ġcan Ġhelp Ġprocess Ġla...
# 4  To Ġdevelop Ġpersonas Ġfurther Ġwhen Ġnew Ġinf...
#
#    engagement_experience_post  interaction_quality_post  \
# 0                           5                         1
# 1                           4                         2
# 2                           3                         4
# 3                           6                         6
# 4                           4                         2
#
#    communication_clarity_post  trustworthiness_post  emotional_response_post  \
# 0                           7                     2                        2
# 1                           4                     4                        2
# 2                           6                     6                        1
# 3                           6                     4                        2
# 4                           3                     3                        1
#
#    naturalness_post  effectiveness_post  comfort_level_post  \
# 0                 1                   6                   6
# 1                 4                   4                   2
# 2                 4                   5                   3
# 3                 3                   6                   1
# 4                 4                   3                   6
#
#    personalization_post  mental_effort_post
# 0                     1                   4
# 1                     2                   6
# 2                     4                   5
# 3                     4                   4
# 4                     1                   6
